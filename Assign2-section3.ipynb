# %%
from itertools import combinations, groupby
import networkx as nx
import random
import matplotlib.pyplot as plt
#Generates a random undirected graph, similarly to an Erdos Reyni graph but this graph is conneted

def gnp_random_connected_graph(n, p):
    
    edges = combinations(range(n), 2)
    G = nx.Graph()
    G.add_nodes_from(range(n))
    if p <= 0:
        return G
    if p >= 1:
        return nx.complete_graph(n, create_using=G)
    for _, node_edges in groupby(edges, key=lambda x: x[0]):
        node_edges = list(node_edges)
        random_edge = random.choice(node_edges)
        G.add_edge(*random_edge)
        for e in node_edges:
            if random.random() < p:
                G.add_edge(*e)
    return G

# %%
nodes = 101
seed = random.randint(1,10)
probability = 0.1
G1 = gnp_random_connected_graph(nodes,probability)

plt.figure(figsize=(10,6))

nx.draw(G1, node_color='yellow', 
        with_labels=True, 
        node_size=500)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(101, 0.01, directed=True))

# %%
numOfNodes = []
for i in range(0, G1.number_of_nodes()):
    numOfNodes.append(i)
s = sorted(G1.degree, key=lambda x: x[1], reverse=True)
degrees = sorted([x[0] for x in s])
frequency = sorted([x[1] for x in s])
plt.loglog(numOfNodes, degrees)
plt.xlabel("Degree")
plt.ylabel("No. of nodes (Frequency)")
plt.title("Degree distribution")
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

x=poisson.rvs(mu=10,size=10000)
plt.hist(x,density=True, edgecolor='black')
# Out:
# (array([0.00477273, 0.02468182, 0.06877273, 0.10845455, 0.11090909,
#         0.10018182, 0.0245    , 0.00886364, 0.00245455, 0.00095455]),
#  array([ 1. ,  3.2,  5.4,  7.6,  9.8, 12. , 14.2, 16.4, 18.6, 20.8, 23. ]),
#  <BarContainer object of 10 artists>)

# %%
nodes = 1001
seed = random.randint(1,10)
probability = 0.01
G2 = gnp_random_connected_graph(nodes,probability)

plt.figure(figsize=(10,6))

nx.draw(G2, node_color='yellow', 
        with_labels=True, 
        node_size=500)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(1001, 0.01, directed=True))

# %%
numOfNodes = []
for i in range(0, G2.number_of_nodes()):
    numOfNodes.append(i)
s = sorted(G2.degree, key=lambda x: x[1], reverse=True)
degrees = sorted([x[0] for x in s])
frequency = sorted([x[1] for x in s])
plt.loglog(numOfNodes, degrees)
plt.xlabel("Degree")
plt.ylabel("No. of nodes (Frequency)")
plt.title("Degree distribution")
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

x=poisson.rvs(mu=10,size=10000)
plt.hist(x,density=True, edgecolor='black')
# Out:
# (array([0.00445833, 0.022125  , 0.112375  , 0.103375  , 0.088625  ,
#         0.06616667, 0.01408333, 0.00479167, 0.00054167, 0.000125  ]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
nodes = 10001
seed = random.randint(1,10)
probability = 0.001
G3 = gnp_random_connected_graph(nodes,probability)

plt.figure(figsize=(10,6))

nx.draw(G3, node_color='yellow', 
        with_labels=True, 
        node_size=500)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(10001, 0.001, directed=True))

# %%
numOfNodes = []
for i in range(0, G3.number_of_nodes()):
    numOfNodes.append(i)
s = sorted(G3.degree, key=lambda x: x[1], reverse=True)
degrees = sorted([x[0] for x in s])
frequency = sorted([x[1] for x in s])
plt.loglog(numOfNodes, degrees)
plt.xlabel("Degree")
plt.ylabel("No. of nodes (Frequency)")
plt.title("Degree distribution")
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

x=poisson.rvs(mu=10,size=10000)
plt.hist(x,density=True, edgecolor='black')
# Out:
# (array([0.00469565, 0.02382609, 0.06608696, 0.15843478, 0.08991304,
#         0.05547826, 0.03095652, 0.00391304, 0.00104348, 0.00043478]),
#  array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
nodes = 100001
seed = random.randint(1,10)
probability = 0.0001
G4 = gnp_random_connected_graph(nodes,probability)

plt.figure(figsize=(10,6))

nx.draw(G4, node_color='yellow', 
        with_labels=True, 
        node_size=500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# t:\SNA\2\section3.ipynb Cell 11 in 8
#       <a href='vscode-notebook-cell:/t%3A/SNA/2/section3.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> G4 = gnp_random_connected_graph(nodes,probability)
#       <a href='vscode-notebook-cell:/t%3A/SNA/2/section3.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> plt.figure(figsize=(10,6))
# ----> <a href='vscode-notebook-cell:/t%3A/SNA/2/section3.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> nx.draw(G4, node_color='yellow',
#       <a href='vscode-notebook-cell:/t%3A/SNA/2/section3.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>         with_labels=True,
#      <a href='vscode-notebook-cell:/t%3A/SNA/2/section3.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>         node_size=500)
#
# File c:\Users\Maryam\AppData\Local\Programs\Python\Python311\Lib\site-packages\networkx\drawing\nx_pylab.py:121, in draw(G, pos, ax, **kwds)
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(100001, 0.0001, directed=True))

# %%
numOfNodes = []
for i in range(0, G4.number_of_nodes()):
    numOfNodes.append(i)
s = sorted(G4.degree, key=lambda x: x[1], reverse=True)
degrees = sorted([x[0] for x in s])
frequency = sorted([x[1] for x in s])
plt.loglog(numOfNodes, degrees)
plt.xlabel("Degree")
plt.ylabel("No. of nodes (Frequency)")
plt.title("Degree distribution")
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

x=poisson.rvs(mu=10,size=10000)
plt.hist(x,density=True, edgecolor='black')

# %%
nodes = 100000
seed = random.randint(1,10)
probability = 0.00001
G5 = gnp_random_connected_graph(nodes,probability)

plt.figure(figsize=(10,6))

nx.draw(G5, node_color='yellow', 
        with_labels=True, 
        node_size=500)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(100000, 0.00001, directed=True))

# %%
numOfNodes = []
for i in range(0, G5.number_of_nodes()):
    numOfNodes.append(i)
s = sorted(G5.degree, key=lambda x: x[1], reverse=True)
degrees = sorted([x[0] for x in s])
frequency = sorted([x[1] for x in s])
plt.loglog(numOfNodes, degrees)
plt.xlabel("Degree")
plt.ylabel("No. of nodes (Frequency)")
plt.title("Degree distribution")
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

x=poisson.rvs(mu=10,size=10000)
plt.hist(x,density=True, edgecolor='black')
